# %%
import pandas as pd
data = pd.read_csv("clean.csv", encoding='utf-8', index_col=0)
data.head()
# Out:
#                              date  retweets  likes  \
# user
# JuniorPardoXVI   2019-06-24 07:58         0      4
# brianfires       2019-06-24 07:55         0      1
# JPM86            2019-06-24 07:54         0      0
# kurirona20       2019-06-24 07:49         0      0
# rqYonvqB9iIBJpm  2019-06-24 07:43         0      1
#
#                                                               text  geo  \
# user
# JuniorPardoXVI   She still had more people at her book signing ...  NaN
# brianfires       Tensions Between The US & # Iran Simmered Over...  NaN
# JPM86            I got engaged in the sand right there!https://...  NaN
# kurirona20       K指数5 日経CNBC JPMシゲミ氏(弱気) もともと弱気派だが、投信のセールスもあるせい...  NaN
# rqYonvqB9iIBJpm   私は、餃子は面倒で造らないんですが。 わたなべ夫婦が造ってると、楽しそうで造ってみたくなります！  NaN
#
#                 mention  tag
# user
# JuniorPardoXVI        @  NaN
# brianfires          @ @    #
# JPM86               NaN  NaN
# kurirona20          NaN  NaN
# rqYonvqB9iIBJpm     NaN  NaN
